# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravi-Poddar26/EDA-Practice/blob/master/EDA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Compenies_of_India.csv")

# %%
data
# Out:
#        Unnamed: 0                   Name   Rating Reviews Average_Package  \
# 0               0                    TCS  ['3.6']   99.3k            9.3L
# 1               1              Accenture  ['3.7']     64k            6.2L
# 2               2                  Wipro  ['3.7']   57.8k            4.6L
# 3               3              Cognizant  ['3.7']     55k            5.9L
# 4               4              Capgemini  ['3.7']   46.6k            4.6L
# ...           ...                    ...      ...     ...             ...
# 10055       10055  The Company of Others  ['4.3']      94            4.8k
# 10056       10056       Desun Technology  ['4.0']      94              53
# 10057       10057    IFL Housing Finance  ['4.0']      94             362
# 10058       10058    Telegence Powercomm  ['3.8']      94             336
# 10059       10059                Binmile  ['3.3']      94             435
#
#       Interwier   Jobs Benefits  \
# 0         11.1k    246      12k
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# Name               0
# Rating             0
# Reviews            0
# Average_Package    0
# Interwier          0
# Jobs               0
# Benefits           0
# Location           0
# dtype: int64

# %%
arr = np.array(data['Rating'])

# %%
arr
# Out:
# array(["['3.6']", "['3.7']", "['3.7']", ..., "['4.0']", "['3.8']",
#        "['3.3']"], dtype=object)

# %%
import ast

# Step 1: Use ast.literal_eval to convert string to list, then extract float
float_arr = np.array([float(ast.literal_eval(item)[0]) for item in arr])

print(float_arr)
# Out:
# [3.6 3.7 3.7 ... 4.  3.8 3.3]

# %%
arr = float_arr

# %%
arr
# Out:
# array([3.6, 3.7, 3.7, ..., 4. , 3.8, 3.3])

# %%
data
# Out:
#        Unnamed: 0                   Name   Rating Reviews Average_Package  \
# 0               0                    TCS  ['3.6']   99.3k            9.3L
# 1               1              Accenture  ['3.7']     64k            6.2L
# 2               2                  Wipro  ['3.7']   57.8k            4.6L
# 3               3              Cognizant  ['3.7']     55k            5.9L
# 4               4              Capgemini  ['3.7']   46.6k            4.6L
# ...           ...                    ...      ...     ...             ...
# 10055       10055  The Company of Others  ['4.3']      94            4.8k
# 10056       10056       Desun Technology  ['4.0']      94              53
# 10057       10057    IFL Housing Finance  ['4.0']      94             362
# 10058       10058    Telegence Powercomm  ['3.8']      94             336
# 10059       10059                Binmile  ['3.3']      94             435
#
#       Interwier   Jobs Benefits  \
# 0         11.1k    246      12k
# ...

# %%
arr1 = np.array(data['Rating'])

# %%
arr1
# Out:
# array(["['3.6']", "['3.7']", "['3.7']", ..., "['4.0']", "['3.8']",
#        "['3.3']"], dtype=object)

# %%
data = data.replace(arr1,arr)
# Out:
# /tmp/ipython-input-28-3275687691.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data = data.replace(arr1,arr)

# %%
data
# Out:
#        Unnamed: 0                   Name  Rating Reviews Average_Package  \
# 0               0                    TCS     3.6   99.3k            9.3L
# 1               1              Accenture     3.7     64k            6.2L
# 2               2                  Wipro     3.7   57.8k            4.6L
# 3               3              Cognizant     3.7     55k            5.9L
# 4               4              Capgemini     3.7   46.6k            4.6L
# ...           ...                    ...     ...     ...             ...
# 10055       10055  The Company of Others     4.3      94            4.8k
# 10056       10056       Desun Technology     4.0      94              53
# 10057       10057    IFL Housing Finance     4.0      94             362
# 10058       10058    Telegence Powercomm     3.8      94             336
# 10059       10059                Binmile     3.3      94             435
#
#       Interwier   Jobs Benefits  \
# 0         11.1k    246      12k
# ...

# %%
data.to_csv("companies_of_India.csv")

# %%
data
# Out:
#        Unnamed: 0                   Name   Rating Reviews Average_Package  \
# 0               0                    TCS  ['3.6']   99.3k            9.3L
# 1               1              Accenture  ['3.7']     64k            6.2L
# 2               2                  Wipro  ['3.7']   57.8k            4.6L
# 3               3              Cognizant  ['3.7']     55k            5.9L
# 4               4              Capgemini  ['3.7']   46.6k            4.6L
# ...           ...                    ...      ...     ...             ...
# 10055       10055  The Company of Others  ['4.3']      94            4.8k
# 10056       10056       Desun Technology  ['4.0']      94              53
# 10057       10057    IFL Housing Finance  ['4.0']      94             362
# 10058       10058    Telegence Powercomm  ['3.8']      94             336
# 10059       10059                Binmile  ['3.3']      94             435
#
#       Interwier   Jobs Benefits  \
# 0         11.1k    246      12k
# ...

# %%
data = pd.read_csv("companies_of_India.csv")

# %%
data
# Out:
#        Unnamed: 0.1  Unnamed: 0                   Name  Rating Reviews  \
# 0                 0           0                    TCS     3.6   99.3k
# 1                 1           1              Accenture     3.7     64k
# 2                 2           2                  Wipro     3.7   57.8k
# 3                 3           3              Cognizant     3.7     55k
# 4                 4           4              Capgemini     3.7   46.6k
# ...             ...         ...                    ...     ...     ...
# 10055         10055       10055  The Company of Others     4.3      94
# 10056         10056       10056       Desun Technology     4.0      94
# 10057         10057       10057    IFL Housing Finance     4.0      94
# 10058         10058       10058    Telegence Powercomm     3.8      94
# 10059         10059       10059                Binmile     3.3      94
#
#       Average_Package Interwier   Jobs Benefits  \
# 0                9.3L     11.1k    246      12k
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1       0
# Unnamed: 0         0
# Name               0
# Rating             0
# Reviews            0
# Average_Package    0
# Interwier          0
# Jobs               0
# Benefits           0
# Location           0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10060 entries, 0 to 10059
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0.1     10060 non-null  int64
#  1   Unnamed: 0       10060 non-null  int64
#  2   Name             10060 non-null  object
#  3   Rating           10060 non-null  float64
#  4   Reviews          10060 non-null  object
#  5   Average_Package  10060 non-null  object
#  6   Interwier        10060 non-null  object
#  7   Jobs             10060 non-null  object
#  8   Benefits         10060 non-null  object
#  9   Location         10060 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 786.1+ KB

# %%
data.describe()
# Out:
#        Unnamed: 0.1    Unnamed: 0        Rating
# count  10060.000000  10060.000000  10060.000000
# mean    5029.500000   5029.500000      3.762684
# std     2904.216188   2904.216188      0.404320
# min        0.000000      0.000000      1.000000
# 25%     2514.750000   2514.750000      3.500000
# 50%     5029.500000   5029.500000      3.800000
# 75%     7544.250000   7544.250000      4.000000
# max    10059.000000  10059.000000      5.000000
